# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %%
tickers = ["AAPL", "MSFT", "TSLA", "GOOGL", "AMZN", "NVDA", "META", "NFLX", "JPM", "XOM", "KO"]

data=yf.download(tickers, period="1y", interval="1d", group_by='ticker', auto_adjust=False)

ticker_dfs={}
for ticker in tickers:
    df=data[ticker].copy()
    df.dropna(inplace=True)
    ticker_dfs[ticker]=df
# Out:
# [*********************100%***********************]  11 of 11 completed

# %%
def compute_ratios(df):
    ratios = {}

    # Daily % Change
    df["pct_change"] = df["Adj Close"].pct_change()

    # Rolling % Changes
    for window, name in [(1, "1D"), (5, "5D"), (21, "1M"), (63, "3M"), (126, "6M"), (252, "1Y")]:
        ratios[f"pct_change_{name}"] = (df["Adj Close"].pct_change(periods=window).iloc[-1])

    # Moving Averages
    for window in [20, 50, 200]:
        ratios[f"SMA_{window}"] = df["Adj Close"].rolling(window).mean().iloc[-1]

    for window in [12, 26]:
        ratios[f"EMA_{window}"] = df["Adj Close"].ewm(span=window, adjust=False).mean().iloc[-1]

    # MACD
    ema12 = df["Adj Close"].ewm(span=12, adjust=False).mean()
    ema26 = df["Adj Close"].ewm(span=26, adjust=False).mean()
    macd = ema12 - ema26
    signal = macd.ewm(span=9, adjust=False).mean()
    ratios["MACD"] = macd.iloc[-1]
    ratios["MACD_signal"] = signal.iloc[-1]

    # RSI
    delta = df["Adj Close"].diff()
    gain = (delta.where(delta > 0, 0)).rolling(14).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(14).mean()
    rs = gain / loss
    ratios["RSI_14"] = 100 - (100 / (1 + rs.iloc[-1]))

    # Bollinger Bands
    sma20 = df["Adj Close"].rolling(20).mean()
    std20 = df["Adj Close"].rolling(20).std()
    ratios["Bollinger_upper"] = sma20.iloc[-1] + (2 * std20.iloc[-1])
    ratios["Bollinger_lower"] = sma20.iloc[-1] - (2 * std20.iloc[-1])

    # ATR
    high_low = df["High"] - df["Low"]
    high_close = (df["High"] - df["Adj Close"].shift()).abs()
    low_close = (df["Low"] - df["Adj Close"].shift()).abs()
    tr = high_low.to_frame(name="hl")
    tr["hc"] = high_close
    tr["lc"] = low_close
    tr = tr.max(axis=1)
    ratios["ATR_14"] = tr.rolling(14).mean().iloc[-1]

    # Historical Volatility (30D)
    log_returns = (df["Adj Close"] / df["Adj Close"].shift(1)).apply(lambda x: np.log(x))
    ratios["HistVol_30D"] = log_returns.rolling(30).std().iloc[-1] * (252 ** 0.5)

    # Volume Averages
    ratios["Vol_Avg_20D"] = df["Volume"].rolling(20).mean().iloc[-1]
    ratios["Vol_Last"] = df["Volume"].iloc[-1]

    # On-Balance Volume (OBV)
    obv = (np.sign(df["Adj Close"].diff()) * df["Volume"]).fillna(0).cumsum()
    ratios["OBV"] = obv.iloc[-1]

    return ratios

# %%
ratios_dict = {}

for ticker, df in ticker_dfs.items():
    ratios_df = compute_ratios(df)  
    ratios_dict[ticker] = ratios_df

# %%
import pprint
pprint.pprint(ratios_dict)
# Out:
# {'AAPL': {'ATR_14': np.float64(4.464287894112723),
#           'Bollinger_lower': np.float64(222.73502571412564),
#           'Bollinger_upper': np.float64(240.5509728210306),
#           'EMA_12': np.float64(232.31586132440032),
#           'EMA_26': np.float64(228.55286304428722),
#           'HistVol_30D': np.float64(0.2938535811730464),
#           'MACD': np.float64(3.762998280113095),
#           'MACD_signal': np.float64(4.787058217862571),
#           'OBV': np.float64(225162200.0),
#           'RSI_14': np.float64(56.751784945407344),
#           'SMA_20': np.float64(231.64299926757812),
#           'SMA_200': np.float64(221.02951309204101),
#           'SMA_50': np.float64(220.56370330810546),
#           'Vol_Avg_20D': np.float64(47816790.0),
#           'Vol_Last': np.int64(50150900),
#           'pct_change_1D': np.float64(0.014286368839370622),
#           'pct_change_1M': np.float64(0.0016547132284436827),
#           'pct_change_1Y': np.float64(nan),
#           'pct_change_3M': np.float64(0.15852230451417482),
#           'pct_change_5D': np.float64(-0.04066227395794719),
#           'pct_change_6M': np.float64(0.06273877306184805)},
#  'AMZN': {'ATR_14': np.float64(4.870714460100446),
#           'Bollinger_lower': np.float64(221.86472188095075),
#           'Bollinger_upper': np.float64(237.75327738662736),
#           'EMA_12': np.float64(231.0507615572109),
#           'EMA_26': np.float64(228.85465415851664),
#           'HistVol_30D': np.float64(0.3751114410469177),
#           'MACD': np.float64(2.1961073986942665),
#           'MACD_signal': np.float64(2.062894653721201),
#           'OBV': np.float64(526950000.0),
#           'RSI_14': np.float64(58.77192865044729),
#           'SMA_20': np.float64(229.80899963378906),
#           'SMA_200': np.float64(213.82080024719238),
#           'SMA_50': np.float64(226.59679992675783),
#           'Vol_Avg_20D': np.float64(35788205.0),
#           'Vol_Last': np.int64(37427500),
#           'pct_change_1D': np.float64(-0.0016498279850283293),
#           'pct_change_1M': np.float64(0.038289590828549436),
#           'pct_change_1Y': np.float64(nan),
#           'pct_change_3M': np.float64(0.07856472907955214),
#           'pct_change_5D': np.float64(-0.024312609918575756),
#           'pct_change_6M': np.float64(0.15616671352964118)},
#  'GOOGL': {'ATR_14': np.float64(6.295772007533482),
#            'Bollinger_lower': np.float64(185.55999863128105),
#            'Bollinger_upper': np.float64(246.86349990387518),
#            'EMA_12': np.float64(227.52130790027246),
#            'EMA_26': np.float64(215.7856610816212),
#            'HistVol_30D': np.float64(0.3167972766793359),
#            'MACD': np.float64(11.735646818651247),
#            'MACD_signal': np.float64(9.346183576447238),
#            'OBV': np.float64(1093007000.0),
#            'RSI_14': np.float64(91.60282039728042),
#            'SMA_20': np.float64(216.2117492675781),
#            'SMA_200': np.float64(180.28967643737792),
#            'SMA_50': np.float64(199.82073211669922),
#            'Vol_Avg_20D': np.float64(36666935.0),
#            'Vol_Last': np.int64(30560400),
#            'pct_change_1D': np.float64(0.005017338953168027),
#            'pct_change_1M': np.float64(0.183166040542333),
#            'pct_change_1Y': np.float64(nan),
#            'pct_change_3M': np.float64(0.3565546693782453),
#            'pct_change_5D': np.float64(0.03566498441955113),
#            'pct_change_6M': np.float64(0.4414231146325205)},
#  'JPM': {'ATR_14': np.float64(5.457855224609375),
#          'Bollinger_lower': np.float64(287.72954042307884),
#          'Bollinger_upper': np.float64(305.90046445973366),
#          'EMA_12': np.float64(298.8523681940534),
#          'EMA_26': np.float64(296.30808988206013),
#          'HistVol_30D': np.float64(0.19239246204313495),
#          'MACD': np.float64(2.544278311993253),
#          'MACD_signal': np.float64(2.3166126786157757),
#          'OBV': np.float64(295942600.0),
#          'RSI_14': np.float64(66.6116424442556),
#          'SMA_20': np.float64(296.81500244140625),
#          'SMA_200': np.float64(261.4344398498535),
#          'SMA_50': np.float64(293.5722009277344),
#          'Vol_Avg_20D': np.float64(7060705.0),
#          'Vol_Last': np.int64(7941100),
#          'pct_change_1D': np.float64(0.01670323042172117),
#          'pct_change_1M': np.float64(0.04340102847935556),
#          'pct_change_1Y': np.float64(nan),
#          'pct_change_3M': np.float64(0.14500118987568467),
#          'pct_change_5D': np.float64(0.005727042961058748),
#          'pct_change_6M': np.float64(0.3555210332328125)},
#  'KO': {'ATR_14': np.float64(0.9199987139020648),
#         'Bollinger_lower': np.float64(66.97656282167206),
#         'Bollinger_upper': np.float64(70.92843672056428),
#         'EMA_12': np.float64(68.31934703691539),
#         'EMA_26': np.float64(68.85626102841277),
#         'HistVol_30D': np.float64(0.13055450414303768),
#         'MACD': np.float64(-0.5369139914973857),
#         'MACD_signal': np.float64(-0.37917055407581784),
#         'OBV': np.float64(-94066000.0),
#         'RSI_14': np.float64(22.363589704464587),
#         'SMA_20': np.float64(68.95249977111817),
#         'SMA_200': np.float64(67.82647621154786),
#         'SMA_50': np.float64(69.41119979858398),
#         'Vol_Avg_20D': np.float64(16521120.0),
#         'Vol_Last': np.int64(15118700),
#         'pct_change_1D': np.float64(-0.0029489376163688297),
#         'pct_change_1M': np.float64(-0.04369956693393828),
#         'pct_change_1Y': np.float64(nan),
#         'pct_change_3M': np.float64(-0.05507443812782731),
#         'pct_change_5D': np.float64(-0.009230728987809078),
#         'pct_change_6M': np.float64(-0.01911169132309365)},
#  'META': {'ATR_14': np.float64(13.549285888671875),
#           'Bollinger_lower': np.float64(726.8893173024215),
#           'Bollinger_upper': np.float64(779.7656692698441),
#           'EMA_12': np.float64(751.5968145624622),
#           'EMA_26': np.float64(749.349786347332),
#           'HistVol_30D': np.float64(0.3960258022892772),
#           'MACD': np.float64(2.2470282151301717),
#           'MACD_signal': np.float64(3.0774754573235263),
#           'OBV': np.float64(211943200.0),
#           'RSI_14': np.float64(56.54685389894929),
#           'SMA_20': np.float64(753.3274932861328),
#           'SMA_200': np.float64(654.1853321838379),
#           'SMA_50': np.float64(740.5923974609375),
#           'Vol_Avg_20D': np.float64(10181380.0),
#           'Vol_Last': np.int64(7913700),
#           'pct_change_1D': np.float64(-0.001436150007629644),
#           'pct_change_1M': np.float64(-0.049493639982199356),
#           'pct_change_1Y': np.float64(nan),
#           'pct_change_3M': np.float64(0.08260262234066995),
#           'pct_change_5D': np.float64(0.0030054096395188967),
#           'pct_change_6M': np.float64(0.21400079790401683)},
#  'MSFT': {'ATR_14': np.float64(7.106434413364956),
#           'Bollinger_lower': np.float64(492.5957286851223),
#           'Bollinger_upper': np.float64(519.732619093198),
#           'EMA_12': np.float64(502.99916948520007),
#           'EMA_26': np.float64(506.0365763497789),
#           'HistVol_30D': np.float64(0.19563164537040592),
#           'MACD': np.float64(-3.037406864578827),
#           'MACD_signal': np.float64(-1.9745660897475126),
#           'OBV': np.float64(347639200.0),
#           'RSI_14': np.float64(46.166656284090465),
#           'SMA_20': np.float64(506.16417388916017),
#           'SMA_200': np.float64(444.28814529418946),
#           'SMA_50': np.float64(509.4270556640625),
#           'Vol_Avg_20D': np.float64(21168470.0),
#           'Vol_Last': np.int64(18654800),
#           'pct_change_1D': np.float64(0.0012790827881028477),
#           'pct_change_1M': np.float64(-0.05178438729988799),
#           'pct_change_1Y': np.float64(nan),
#           'pct_change_3M': np.float64(0.061812080992691865),
#           'pct_change_5D': np.float64(-0.013701579696345334),
#           'pct_change_6M': np.float64(0.3117512875933759)},
#  'NFLX': {'ATR_14': np.float64(27.242850167410715),
#           'Bollinger_lower': np.float64(1192.0048100601364),
#           'Bollinger_upper': np.float64(1264.159166990645),
#           'EMA_12': np.float64(1231.729391805724),
#           'EMA_26': np.float64(1225.0116465612452),
#           'HistVol_30D': np.float64(0.24689086311218242),
#           'MACD': np.float64(6.717745244478692),
#           'MACD_signal': np.float64(6.316366596932522),
#           'OBV': np.float64(138192000.0),
#           'RSI_14': np.float64(49.31845393424001),
#           'SMA_20': np.float64(1228.0819885253907),
#           'SMA_200': np.float64(1070.1268478393554),
#           'SMA_50': np.float64(1221.8565966796875),
#           'Vol_Avg_20D': np.float64(2720600.0),
#           'Vol_Last': np.int64(5674900),
#           'pct_change_1D': np.float64(-0.03543288289874813),
#           'pct_change_1M': np.float64(-0.017775552344041268),
#           'pct_change_1Y': np.float64(nan),
#           'pct_change_3M': np.float64(-0.01342755419979691),
#           'pct_change_5D': np.float64(-0.04292710922413878),
#           'pct_change_6M': np.float64(0.3086073521056525)},
#  'NVDA': {'ATR_14': np.float64(5.414954049246652),
#           'Bollinger_lower': np.float64(166.31796823518454),
#           'Bollinger_upper': np.float64(185.6301823995811),
#           'EMA_12': np.float64(174.20230730302995),
#           'EMA_26': np.float64(174.50537382385403),
#           'HistVol_30D': np.float64(0.2689611929899423),
#           'MACD': np.float64(-0.3030665208240748),
#           'MACD_signal': np.float64(0.21871295806194194),
#           'OBV': np.float64(2587051200.0),
#           'RSI_14': np.float64(53.22769498460381),
#           'SMA_20': np.float64(175.9740753173828),
#           'SMA_200': np.float64(139.7938040924072),
#           'SMA_50': np.float64(173.69960540771484),
#           'Vol_Avg_20D': np.float64(184217625.0),
#           'Vol_Last': np.int64(150849700),
#           'pct_change_1D': np.float64(-0.0008459798617036496),
#           'pct_change_1M': np.float64(-0.03264911795877279),
#           'pct_change_1Y': np.float64(nan),
#           'pct_change_3M': np.float64(0.24049562504360322),
#           'pct_change_5D': np.float64(0.03215646944745609),
#           'pct_change_6M': np.float64(0.530951160523893)},
#  'TSLA': {'ATR_14': np.float64(12.846420288085938),
#           'Bollinger_lower': np.float64(317.3468943244826),
#           'Bollinger_upper': np.float64(363.1671040886033),
#           'EMA_12': np.float64(346.1550338061724),
#           'EMA_26': np.float64(338.88468858774274),
#           'HistVol_30D': np.float64(0.37647504096825063),
#           'MACD': np.float64(7.270345218429668),
#           'MACD_signal': np.float64(5.543900176429525),
#           'OBV': np.float64(1033788400.0),
#           'RSI_14': np.float64(73.82582059976852),
#           'SMA_20': np.float64(340.25699920654296),
#           'SMA_200': np.float64(330.51869987487794),
#           'SMA_50': np.float64(326.9173992919922),
#           'Vol_Avg_20D': np.float64(75422665.0),
#           'Vol_Last': np.int64(103116100),
#           'pct_change_1D': np.float64(0.06043873744853956),
#           'pct_change_1M': np.float64(0.08206196902130913),
#           'pct_change_1Y': np.float64(nan),
#           'pct_change_3M': np.float64(0.1298287713559012),
#           'pct_change_5D': np.float64(0.08944554068615296),
#           'pct_change_6M': np.float64(0.4865976178107816)},
#  'XOM': {'ATR_14': np.float64(2.002143314906529),
#          'Bollinger_lower': np.float64(105.53590980229664),
#          'Bollinger_upper': np.float64(115.76909050287914),
#          'EMA_12': np.float64(111.35663802503164),
#          'EMA_26': np.float64(110.49894098537125),
#          'HistVol_30D': np.float64(0.18165509425838056),
#          'MACD': np.float64(0.857697039660394),
#          'MACD_signal': np.float64(0.8752224396926451),
#          'OBV': np.float64(117793900.0),
#          'RSI_14': np.float64(59.076723765791264),
#          'SMA_20': np.float64(110.65250015258789),
#          'SMA_200': np.float64(107.86526027679443),
#          'SMA_50': np.float64(109.84749328613282),
#          'Vol_Avg_20D': np.float64(14815925.0),
#          'Vol_Last': np.int64(11533600),
#          'pct_change_1D': np.float64(-0.003200005425347263),
#          'pct_change_1M': np.float64(0.0664610424003913),
#          'pct_change_1Y': np.float64(nan),
#          'pct_change_3M': np.float64(0.03543594831194108),
#          'pct_change_5D': np.float64(-0.0023131862339931253),
#          'pct_change_6M': np.float64(0.04669608556090021)}}

# %%
import numpy as np

def interpret_rsi(rsi):
    if rsi > 70:
        return "overbought"
    elif rsi < 30:
        return "oversold"
    else:
        return "neutral"

def interpret_macd(macd, signal):
    if macd > signal:
        return "bullish"
    elif macd < signal:
        return "bearish"
    else:
        return "neutral"

def interpret_volume(last, avg):
    if last > avg:
        return "higher than average"
    elif last < avg:
        return "lower than average"
    else:
        return "about average"

def interpret_obv(obv_change):
    if obv_change > 0:
        return "buying pressure"
    elif obv_change < 0:
        return "selling pressure"
    else:
        return "neutral"

def create_summary(ticker, data_dict):
    # Trend & Momentum
    trend_text = f"""[Trend & Momentum]
Price Changes:
- 1 Day: {data_dict['pct_change_1D']:.2%}, 5 Days: {data_dict['pct_change_5D']:.2%}, 1 Month: {data_dict['pct_change_1M']:.2%}, 3 Months: {data_dict['pct_change_3M']:.2%}, 6 Months: {data_dict['pct_change_6M']:.2%}, 1 Year: {data_dict.get('pct_change_1Y','N/A')}

SMA/EMA:
- SMA20: {data_dict['SMA_20']:.2f}, SMA50: {data_dict['SMA_50']:.2f}, SMA200: {data_dict['SMA_200']:.2f}
- EMA12: {data_dict['EMA_12']:.2f}, EMA26: {data_dict['EMA_26']:.2f}

Momentum Indicators:
- RSI(14): {data_dict['RSI_14']:.1f} ({interpret_rsi(data_dict['RSI_14'])})
- MACD: {data_dict['MACD']:.2f}, Signal Line: {data_dict['MACD_signal']:.2f} ({interpret_macd(data_dict['MACD'], data_dict['MACD_signal'])})
"""

    # Volatility & Risk
    volatility_text = f"""[Volatility & Risk]
Bollinger Bands (20-day):
- Lower: {data_dict['Bollinger_lower']:.2f}, Upper: {data_dict['Bollinger_upper']:.2f}
ATR(14): {data_dict['ATR_14']:.2f}
Historical Volatility (30D): {data_dict['HistVol_30D']:.2%}
Beta vs S&P500: {data_dict.get('Beta','N/A')}
"""

    # Volume Signals
    volume_text = f"""[Volume Signals]
Volume:
- 20-day Average: {data_dict['Vol_Avg_20D']:.0f}, Last Day: {data_dict['Vol_Last']:.0f} ({interpret_volume(data_dict['Vol_Last'], data_dict['Vol_Avg_20D'])})
OBV: {data_dict['OBV']:.0f} ({interpret_obv(data_dict['OBV'])})
"""

    return {
        "ticker": ticker,
        "trend": trend_text,
        "volatility": volatility_text,
        "volume": volume_text
    }


for ticker in tickers:
    summary = create_summary(ticker, ratios_dict[ticker])
    print(f"--- Summary for {ticker} ---")
    print(summary['trend'])
    print(summary['volatility'])
    print(summary['volume'])
# Out:
# --- Summary for AAPL ---
# [Trend & Momentum]
# Price Changes:
# - 1 Day: 1.43%, 5 Days: -4.07%, 1 Month: 0.17%, 3 Months: 15.85%, 6 Months: 6.27%, 1 Year: nan
#
# SMA/EMA:
# - SMA20: 231.64, SMA50: 220.56, SMA200: 221.03
# - EMA12: 232.32, EMA26: 228.55
#
# Momentum Indicators:
# - RSI(14): 56.8 (neutral)
# - MACD: 3.76, Signal Line: 4.79 (bearish)
#
# [Volatility & Risk]
# Bollinger Bands (20-day):
# - Lower: 222.74, Upper: 240.55
# ATR(14): 4.46
# Historical Volatility (30D): 29.39%
# Beta vs S&P500: N/A
#
# [Volume Signals]
# Volume:
# - 20-day Average: 47816790, Last Day: 50150900 (higher than average)
# OBV: 225162200 (buying pressure)
#
# --- Summary for MSFT ---
# [Trend & Momentum]
# Price Changes:
# - 1 Day: 0.13%, 5 Days: -1.37%, 1 Month: -5.18%, 3 Months: 6.18%, 6 Months: 31.18%, 1 Year: nan
#
# SMA/EMA:
# - SMA20: 506.16, SMA50: 509.43, SMA200: 444.29
# - EMA12: 503.00, EMA26: 506.04
#
# Momentum Indicators:
# - RSI(14): 46.2 (neutral)
# - MACD: -3.04, Signal Line: -1.97 (bearish)
#
# [Volatility & Risk]
# Bollinger Bands (20-day):
# - Lower: 492.60, Upper: 519.73
# ATR(14): 7.11
# Historical Volatility (30D): 19.56%
# Beta vs S&P500: N/A
#
# [Volume Signals]
# Volume:
# - 20-day Average: 21168470, Last Day: 18654800 (lower than average)
# OBV: 347639200 (buying pressure)
#
# --- Summary for TSLA ---
# [Trend & Momentum]
# Price Changes:
# - 1 Day: 6.04%, 5 Days: 8.94%, 1 Month: 8.21%, 3 Months: 12.98%, 6 Months: 48.66%, 1 Year: nan
#
# SMA/EMA:
# - SMA20: 340.26, SMA50: 326.92, SMA200: 330.52
# - EMA12: 346.16, EMA26: 338.88
#
# Momentum Indicators:
# - RSI(14): 73.8 (overbought)
# - MACD: 7.27, Signal Line: 5.54 (bullish)
#
# [Volatility & Risk]
# Bollinger Bands (20-day):
# - Lower: 317.35, Upper: 363.17
# ATR(14): 12.85
# Historical Volatility (30D): 37.65%
# Beta vs S&P500: N/A
#
# [Volume Signals]
# Volume:
# - 20-day Average: 75422665, Last Day: 103116100 (higher than average)
# OBV: 1033788400 (buying pressure)
#
# --- Summary for GOOGL ---
# [Trend & Momentum]
# Price Changes:
# - 1 Day: 0.50%, 5 Days: 3.57%, 1 Month: 18.32%, 3 Months: 35.66%, 6 Months: 44.14%, 1 Year: nan
#
# SMA/EMA:
# - SMA20: 216.21, SMA50: 199.82, SMA200: 180.29
# - EMA12: 227.52, EMA26: 215.79
#
# Momentum Indicators:
# - RSI(14): 91.6 (overbought)
# - MACD: 11.74, Signal Line: 9.35 (bullish)
#
# [Volatility & Risk]
# Bollinger Bands (20-day):
# - Lower: 185.56, Upper: 246.86
# ATR(14): 6.30
# Historical Volatility (30D): 31.68%
# Beta vs S&P500: N/A
#
# [Volume Signals]
# Volume:
# - 20-day Average: 36666935, Last Day: 30560400 (lower than average)
# OBV: 1093007000 (buying pressure)
#
# --- Summary for AMZN ---
# [Trend & Momentum]
# Price Changes:
# - 1 Day: -0.16%, 5 Days: -2.43%, 1 Month: 3.83%, 3 Months: 7.86%, 6 Months: 15.62%, 1 Year: nan
#
# SMA/EMA:
# - SMA20: 229.81, SMA50: 226.60, SMA200: 213.82
# - EMA12: 231.05, EMA26: 228.85
#
# Momentum Indicators:
# - RSI(14): 58.8 (neutral)
# - MACD: 2.20, Signal Line: 2.06 (bullish)
#
# [Volatility & Risk]
# Bollinger Bands (20-day):
# - Lower: 221.86, Upper: 237.75
# ATR(14): 4.87
# Historical Volatility (30D): 37.51%
# Beta vs S&P500: N/A
#
# [Volume Signals]
# Volume:
# - 20-day Average: 35788205, Last Day: 37427500 (higher than average)
# OBV: 526950000 (buying pressure)
#
# --- Summary for NVDA ---
# [Trend & Momentum]
# Price Changes:
# - 1 Day: -0.08%, 5 Days: 3.22%, 1 Month: -3.26%, 3 Months: 24.05%, 6 Months: 53.10%, 1 Year: nan
#
# SMA/EMA:
# - SMA20: 175.97, SMA50: 173.70, SMA200: 139.79
# - EMA12: 174.20, EMA26: 174.51
#
# Momentum Indicators:
# - RSI(14): 53.2 (neutral)
# - MACD: -0.30, Signal Line: 0.22 (bearish)
#
# [Volatility & Risk]
# Bollinger Bands (20-day):
# - Lower: 166.32, Upper: 185.63
# ATR(14): 5.41
# Historical Volatility (30D): 26.90%
# Beta vs S&P500: N/A
#
# [Volume Signals]
# Volume:
# - 20-day Average: 184217625, Last Day: 150849700 (lower than average)
# OBV: 2587051200 (buying pressure)
#
# --- Summary for META ---
# [Trend & Momentum]
# Price Changes:
# - 1 Day: -0.14%, 5 Days: 0.30%, 1 Month: -4.95%, 3 Months: 8.26%, 6 Months: 21.40%, 1 Year: nan
#
# SMA/EMA:
# - SMA20: 753.33, SMA50: 740.59, SMA200: 654.19
# - EMA12: 751.60, EMA26: 749.35
#
# Momentum Indicators:
# - RSI(14): 56.5 (neutral)
# - MACD: 2.25, Signal Line: 3.08 (bearish)
#
# [Volatility & Risk]
# Bollinger Bands (20-day):
# - Lower: 726.89, Upper: 779.77
# ATR(14): 13.55
# Historical Volatility (30D): 39.60%
# Beta vs S&P500: N/A
#
# [Volume Signals]
# Volume:
# - 20-day Average: 10181380, Last Day: 7913700 (lower than average)
# OBV: 211943200 (buying pressure)
#
# --- Summary for NFLX ---
# [Trend & Momentum]
# Price Changes:
# - 1 Day: -3.54%, 5 Days: -4.29%, 1 Month: -1.78%, 3 Months: -1.34%, 6 Months: 30.86%, 1 Year: nan
#
# SMA/EMA:
# - SMA20: 1228.08, SMA50: 1221.86, SMA200: 1070.13
# - EMA12: 1231.73, EMA26: 1225.01
#
# Momentum Indicators:
# - RSI(14): 49.3 (neutral)
# - MACD: 6.72, Signal Line: 6.32 (bullish)
#
# [Volatility & Risk]
# Bollinger Bands (20-day):
# - Lower: 1192.00, Upper: 1264.16
# ATR(14): 27.24
# Historical Volatility (30D): 24.69%
# Beta vs S&P500: N/A
#
# [Volume Signals]
# Volume:
# - 20-day Average: 2720600, Last Day: 5674900 (higher than average)
# OBV: 138192000 (buying pressure)
#
# --- Summary for JPM ---
# [Trend & Momentum]
# Price Changes:
# - 1 Day: 1.67%, 5 Days: 0.57%, 1 Month: 4.34%, 3 Months: 14.50%, 6 Months: 35.55%, 1 Year: nan
#
# SMA/EMA:
# - SMA20: 296.82, SMA50: 293.57, SMA200: 261.43
# - EMA12: 298.85, EMA26: 296.31
#
# Momentum Indicators:
# - RSI(14): 66.6 (neutral)
# - MACD: 2.54, Signal Line: 2.32 (bullish)
#
# [Volatility & Risk]
# Bollinger Bands (20-day):
# - Lower: 287.73, Upper: 305.90
# ATR(14): 5.46
# Historical Volatility (30D): 19.24%
# Beta vs S&P500: N/A
#
# [Volume Signals]
# Volume:
# - 20-day Average: 7060705, Last Day: 7941100 (higher than average)
# OBV: 295942600 (buying pressure)
#
# --- Summary for XOM ---
# [Trend & Momentum]
# Price Changes:
# - 1 Day: -0.32%, 5 Days: -0.23%, 1 Month: 6.65%, 3 Months: 3.54%, 6 Months: 4.67%, 1 Year: nan
#
# SMA/EMA:
# - SMA20: 110.65, SMA50: 109.85, SMA200: 107.87
# - EMA12: 111.36, EMA26: 110.50
#
# Momentum Indicators:
# - RSI(14): 59.1 (neutral)
# - MACD: 0.86, Signal Line: 0.88 (bearish)
#
# [Volatility & Risk]
# Bollinger Bands (20-day):
# - Lower: 105.54, Upper: 115.77
# ATR(14): 2.00
# Historical Volatility (30D): 18.17%
# Beta vs S&P500: N/A
#
# [Volume Signals]
# Volume:
# - 20-day Average: 14815925, Last Day: 11533600 (lower than average)
# OBV: 117793900 (buying pressure)
#
# --- Summary for KO ---
# [Trend & Momentum]
# Price Changes:
# - 1 Day: -0.29%, 5 Days: -0.92%, 1 Month: -4.37%, 3 Months: -5.51%, 6 Months: -1.91%, 1 Year: nan
#
# SMA/EMA:
# - SMA20: 68.95, SMA50: 69.41, SMA200: 67.83
# - EMA12: 68.32, EMA26: 68.86
#
# Momentum Indicators:
# - RSI(14): 22.4 (oversold)
# - MACD: -0.54, Signal Line: -0.38 (bearish)
#
# [Volatility & Risk]
# Bollinger Bands (20-day):
# - Lower: 66.98, Upper: 70.93
# ATR(14): 0.92
# Historical Volatility (30D): 13.06%
# Beta vs S&P500: N/A
#
# [Volume Signals]
# Volume:
# - 20-day Average: 16521120, Last Day: 15118700 (lower than average)
# OBV: -94066000 (selling pressure)

# %%
import pinecone
from pinecone import ServerlessSpec
from sentence_transformers import SentenceTransformer
import os
from dotenv import load_dotenv

load_dotenv()

PINECONE_API=os.getenv("PINECONE_API")
pc=pinecone.Pinecone(api_key=PINECONE_API)
index_name="ticker-ratios"

if index_name not in pc.list_indexes().names():
            pc.create_index(
                name=index_name,
                dimension=384,
                metric='cosine',
                spec=ServerlessSpec(cloud='aws', region='us-east-1')
            )

index=pc.Index(index_name)
model=SentenceTransformer("all-MiniLM-L6-v2")

for ticker in tickers:
    summary = create_summary(ticker, ratios_dict[ticker])

    embedding_trend=model.encode(summary['trend'])
    embedding_volatility=model.encode(summary['volatility'])
    embedding_volume=model.encode(summary['volume'])

    upsert_items=[
  (f"{ticker}_trend", 
   embedding_trend, 
   {"text": summary["trend"], "ticker": ticker, "section": "trend"}),
  (f"{ticker}_volatility", 
   embedding_volatility, 
   {"text": summary["volatility"], "ticker": ticker, "section": "volatility"}),
  (f"{ticker}_volume", 
   embedding_volume, 
   {"text": summary["volume"], "ticker": ticker, "section": "volume"})]
    
    index.upsert(upsert_items)
